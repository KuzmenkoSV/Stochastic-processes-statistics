# %%
pip install git+https://github.com/jkirkby3/pymle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/jkirkby3/pymle
#   Cloning https://github.com/jkirkby3/pymle to /tmp/pip-req-build-6fp5ti7_
#   Running command git clone -q https://github.com/jkirkby3/pymle /tmp/pip-req-build-6fp5ti7_
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from PyMLE==0.0.1) (1.21.6)
# Building wheels for collected packages: PyMLE
#   Building wheel for PyMLE (PEP 517) ... done
#   Created wheel for PyMLE: filename=PyMLE-0.0.1-py3-none-any.whl size=38015 sha256=e5854baca4a6dfaa80f067ecfeca3dbe96231309c80c5ba2f391436c6b625e73
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9l0w4stn/wheels/cd/1e/47/b1240ec565910918e972d8bc400bc27859de0658a5cc94b937
# Successfully built PyMLE
# Installing collected packages: PyMLE
# Successfully installed PyMLE-0.0.1

# %% [markdown]
# # **1) Генерация OU и оценка его параметров**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

from scipy.stats import norm

from pymle.models import OrnsteinUhlenbeck
from pymle.sim.Simulator1D import Simulator1D
from pymle.TransitionDensity import ExactDensity
from pymle.TransitionDensity import EulerDensity
from pymle.fit.AnalyticalMLE import AnalyticalMLE

# %%
def OU(X, kappa, mu, sigma, dW, dt):
  dX = kappa * (mu - X) * dt + sigma * dW
  return dX

# %%
def beta1(X, n):
  sum1, sum2, sum3, sum4 = 0, 0, 0, 0
  for i in range(1, n):
    sum1 += X[i] * X[i - 1]
    sum2 += X[i]
    sum3 += X[i - 1]
    sum4 += X[i - 1]**2
  bet1 = (sum1 / n - sum2 * sum3 / n**2) / (sum4 / n - sum3**2 / n**2)
  return bet1


def beta2(X, n, b1):
  sum = 0
  for i in range (1, n):
    sum += (X[i] - b1 * X[i - 1])
  res = (sum / n) / (1 - b1)
  return res

def beta3 (X, n, b1, b2):
  sum = 0
  for i in range (1, n):
    sum += (X[i] - b1 * X [i - 1] - b2 * (1 - b1))** 2
  res = sum / (n * b1)
  return res

# %%
kappa = 3
mu = 1
sigma = 2
N = 1000
delta = 1 / N
dW = np.random.normal(0, np.sqrt(1 / N), N)

X_ou = np.zeros(N)
X_ou[0] = 10
for i in range(1, N):
    dX = OU(X_ou[i - 1], kappa, mu, sigma, dW[i], delta)
    X_ou[i] = X_ou[i - 1] + dX

# %%
b_1 = beta1(X_ou, len(X_ou))
b_2 = beta2(X_ou, len(X_ou), b_1)
b_3 = beta3(X_ou, len(X_ou), b_1, b_2)

kappa_est= (-1 / delta) * np.log(b_1)
mu_est = b_2
sigma_est = (2 * kappa_est * b_3 / (1 - b_1 ** 2))**0.5

print('kappa_estimation =', kappa_est)
print('mu_estimation =', mu_est)
print('sigma_estimation =', sigma_est)
# Out:
# kappa_estimation = 3.217928703122882
# mu_estimation = 0.9220942927849521
# sigma_estimation = 1.9712367947016276

# %% [markdown]
# Через библиотекку

# %%
model = OrnsteinUhlenbeck()  

kappa = 3  # rate of mean reversion
mu = 1  # long term level of process
sigma = 2  # volatility

model.params = np.array([kappa, mu, sigma])


S0 = 10  # initial value of process
T = 1000  # number of days of the sample
freq = 1  # observations per day
dt = 1. / freq
seed = 123  # random seed: set to None to get new results each time

#simulator = Simulator1D(S0=S0, M=T * freq, dt=dt, model=model).set_seed(seed=seed)
#sample = simulator.sim_path()



param_bounds = [(0, 6), (0, 6), (0, 6)]

guess = np.array([1, 0.1, 1])

exact_est = AnalyticalMLE(X_ou, param_bounds, dt, density=ExactDensity(model)).estimate_params(guess)

print(f'\nExact MLE: {exact_est}')
# Out:
# Initial Params: [1.  0.1 1. ]
# Initial Likelihood: -9556.177848045578
# `xtol` termination condition is satisfied.
# Number of iterations: 72, function evaluations: 264, CG iterations: 138, optimality: 1.28e-05, constraint violation: 0.00e+00, execution time: 0.28 s.
# Final Params: [0.00299477 0.92357542 0.06136852]
# Final Likelihood: 1372.042837996194
#
# Exact MLE:
# params      | [0.00299477 0.92357542 0.06136852]
# sample size | 999
# likelihood  | 1372.042837996194
# AIC         | -2738.085675992388
# BIC         | -2723.3654116564426
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '

# %% [markdown]
# # **Задача 2) Явная оценка парметров и оценка методом эйлера**

# %%
kappa = 0
alpha = 3
sigma = 2
N = 1000
delta = 1 / N
dW = np.random.normal(0, np.sqrt(1 / N), N)

# %%
def theta_2(X, delta, n):
  t1 = 0
  t2 = 0
  for i in range(1, n):
    t1 += X[i] * X[i - 1]
    t2 += X[i-1] ** 2
  t_2 = -np.log(t1 / t2) / delta
  return t_2

def theta_3(X, delta, n, t_2):
  t1 = 0
  t2 = 0
  for i in range(1, n):
    t1 += (X[i] - X[i - 1] * np.exp(-delta * t_2)) ** 2 
  t2 = (2 * t_2) / (n * (1 - np.exp(-2 * delta * t_2)))
  return t1 * t2

# %%
X_ou = np.zeros(N)
X_ou[0] = 10
for i in range(1, N):
    dX = OU(X_ou[i - 1], 3, 0, 2, dW[i], 1 / N)
    X_ou[i] = X_ou[i - 1] + dX

# %%
theta2_est = theta_2(X_ou, delta, len(X_ou))
theta3_est = theta_3(X_ou, delta, len(X_ou), theta2_est) ** 0.5


print('Theta_2=', theta2_est)
print('Theta_3=', theta3_est)
# Out:
# Theta_2= 2.7727369823533032
# Theta_3= 2.030540077710983

# %% [markdown]
# Через библиотеку:

# %%
model = OrnsteinUhlenbeck()  
model.params = np.array([kappa, mu, sigma])

# ===========================
# Simulate a sample path (we will fit to this path)
# ===========================
S0 = 10  # initial value of process
T = 1000  # num years of the sample
freq = 1  # observations per year
dt = 1. / freq
seed = 123  # random seed: set to None to get new results each time

X = X_ou


X = np.array(X).reshape(-1)
# ===========================
# Fit maximum Likelihood estimators
# ===========================
# Set the parameter bounds for fitting  (kappa, mu, sigma)
param_bounds = [(-1, 5), (-1, 5), (-1, 5)]

# Choose some initial guess for params fit
guess = np.array([0.5, 0.1, 0.4])

# Fit using Exact MLE
exact_est = AnalyticalMLE(X, param_bounds, dt, density=ExactDensity(model)).estimate_params(guess)

# Fit using Euler MLE
euler_est = AnalyticalMLE(X, param_bounds, dt, density=EulerDensity(model)).estimate_params(guess)


print(f'\nExact MLE:\n', exact_est)

print(f'\nEuler MLE:', euler_est)
# Out:
# Initial Params: [0.5 0.1 0.4]
# Initial Likelihood: -13993.141847594055
# `xtol` termination condition is satisfied.
# Number of iterations: 82, function evaluations: 384, CG iterations: 209, optimality: 6.32e-03, constraint violation: 0.00e+00, execution time: 0.36 s.
# Final Params: [0.00369219 1.55508991 0.06265772]
# Final Likelihood: 1351.62178702136
# Initial Params: [0.5 0.1 0.4]
# Initial Likelihood: -14529.904361718482
# `xtol` termination condition is satisfied.
# Number of iterations: 70, function evaluations: 328, CG iterations: 170, optimality: 1.21e-03, constraint violation: 0.00e+00, execution time: 0.26 s.
# Final Params: [0.0036853  1.55498825 0.06254223]
# Final Likelihood: 1351.6217869906354
#
# Exact MLE:
#
# params      | [0.00369219 1.55508991 0.06265772]
# sample size | 999
# likelihood  | 1351.62178702136
# AIC         | -2697.24357404272
# BIC         | -2682.5233097067744
#
# Euler MLE:
# params      | [0.0036853  1.55498825 0.06254223]
# sample size | 999
# likelihood  | 1351.6217869906354
# AIC         | -2697.243573981271
# BIC         | -2682.5233096453253

# %% [markdown]
# # **Задача 3)**

# %%
from pymle.models import CKLS
import scipy.stats as st


model = CKLS()  
model.params = np.array([1, 2, 0.5, 0.3])

S0 = 2  # initial value of process
T = 2  # num years of the sample
freq = 1000  # observations per year
dt = 1. / freq
seed = None#123  # random seed: set to None to get new results each time

simulator = Simulator1D(S0=S0, M=T * freq, dt=dt, model=model).set_seed(seed=seed)
sample = simulator.sim_path()

param_bounds = [(0, 5), (0, 5), (0, 5), (0, 5)]

guess = np.array([0.5, 0.9, 0.9, 0.9])

theta1 = []
theta2 = []
theta3 = []
theta4 = []

for i in range (0, 100):
    print(i)
    simulator = Simulator1D(S0=S0, M=T * freq, dt=dt, model=model).set_seed(seed=seed)
    sample = simulator.sim_path()
    euler_est = AnalyticalMLE(sample, param_bounds, dt, density=EulerDensity(model)).estimate_params(guess)
    theta1.append(euler_est.params[0])
    theta2.append(euler_est.params[1])
    theta3.append(euler_est.params[2])
    theta4.append(euler_est.params[3])

print("Theta_1: ", st.t.interval(alpha=0.95, df=len(theta1)-1, loc=np.mean(theta1), scale=st.sem(theta1)))

print("Theta_2: ", st.t.interval(alpha=0.95, df=len(theta2)-1, loc=np.mean(theta2), scale=st.sem(theta2)) )

print("Theta_3: ", st.t.interval(alpha=0.95, df=len(theta3)-1, loc=np.mean(theta3), scale=st.sem(theta3)))

print("Theta_4: ", st.t.interval(alpha=0.95, df=len(theta4)-1, loc=np.mean(theta4), scale=st.sem(theta4)))

print(f'\nEuler MLE: {euler_est} ')
# Out:
# 0
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 160.02364743459714
# `xtol` termination condition is satisfied.
# Number of iterations: 69, function evaluations: 325, CG iterations: 202, optimality: 1.18e-04, constraint violation: 0.00e+00, execution time: 0.34 s.
# Final Params: [0.33853504 2.04491069 0.51187193 0.28481604]
# Final Likelihood: 3797.1728816640857
# 1
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 164.05280359245307
# `xtol` termination condition is satisfied.
# Number of iterations: 53, function evaluations: 210, CG iterations: 154, optimality: 1.24e-05, constraint violation: 0.00e+00, execution time: 0.23 s.
# Final Params: [0.70586542 2.0357304  0.51586934 0.28830075]
# Final Likelihood: 3763.9406642620143
# 2
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 37.3926400731915
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 315, CG iterations: 173, optimality: 1.05e-04, constraint violation: 0.00e+00, execution time: 0.32 s.
# Final Params: [1.44677689 1.98631838 0.50820701 0.28944031]
# Final Likelihood: 3745.9844702193222
# 3
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 21.78768636424934
# `xtol` termination condition is satisfied.
# Number of iterations: 59, function evaluations: 285, CG iterations: 173, optimality: 1.29e-04, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [1.06190309 1.99492281 0.4570422  0.33045898]
# Final Likelihood: 3713.7618386321374
# 4
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -122.87292503545268
# `xtol` termination condition is satisfied.
# Number of iterations: 78, function evaluations: 380, CG iterations: 212, optimality: 2.20e-04, constraint violation: 0.00e+00, execution time: 0.38 s.
# Final Params: [1.84428769 1.99076892 0.45381575 0.34046047]
# Final Likelihood: 3615.1462253414415
# 5
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 206.42808581827398
# `xtol` termination condition is satisfied.
# Number of iterations: 58, function evaluations: 235, CG iterations: 177, optimality: 3.26e-05, constraint violation: 0.00e+00, execution time: 0.27 s.
# Final Params: [0.56447611 2.02503963 0.44640979 0.34813384]
# Final Likelihood: 3730.6123606316864
# 6
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 63.757138048207594
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 295, CG iterations: 175, optimality: 1.02e-05, constraint violation: 0.00e+00, execution time:  0.3 s.
# Final Params: [0.72256583 2.10278647 0.40187635 0.37423108]
# Final Likelihood: 3733.98572305124
# 7
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 272.1054405938904
# `xtol` termination condition is satisfied.
# Number of iterations: 95, function evaluations: 460, CG iterations: 275, optimality: 2.00e-04, constraint violation: 0.00e+00, execution time: 0.48 s.
# Final Params: [0.28219692 2.06748569 0.38416202 0.38030474]
# Final Likelihood: 3876.9940957458557
# 8
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 63.090710917032766
# `xtol` termination condition is satisfied.
# Number of iterations: 79, function evaluations: 380, CG iterations: 243, optimality: 6.72e-05, constraint violation: 0.00e+00, execution time: 0.39 s.
# Final Params: [0.77157788 2.05642491 0.40279291 0.37317091]
# Final Likelihood: 3734.6661275964952
# 9
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 432.3169595465022
# `xtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 255, CG iterations: 163, optimality: 6.21e-05, constraint violation: 0.00e+00, execution time: 0.26 s.
# Final Params: [8.06767976e-05 2.07389786e+00 3.79522806e-01 3.96908319e-01]
# Final Likelihood: 3880.520403535868
# 10
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 72.46519793168704
# `xtol` termination condition is satisfied.
# Number of iterations: 52, function evaluations: 225, CG iterations: 158, optimality: 2.30e-05, constraint violation: 0.00e+00, execution time: 0.24 s.
# Final Params: [0.40690664 2.04788926 0.39278934 0.38019382]
# Final Likelihood: 3747.74395500559
# 11
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 266.22962867755643
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 320, CG iterations: 175, optimality: 1.94e-04, constraint violation: 0.00e+00, execution time: 0.32 s.
# Final Params: [0.39911779 2.05259467 0.37592884 0.39328393]
# Final Likelihood: 3845.7395722870197
# 12
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -42.48643816495792
# `xtol` termination condition is satisfied.
# Number of iterations: 51, function evaluations: 245, CG iterations: 149, optimality: 8.15e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [1.24092973 2.05314141 0.37440598 0.39931286]
# Final Likelihood: 3682.264353762465
# 13
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -123.99292551079748
# `xtol` termination condition is satisfied.
# Number of iterations: 71, function evaluations: 360, CG iterations: 200, optimality: 7.71e-05, constraint violation: 0.00e+00, execution time: 0.32 s.
# Final Params: [1.55376513 2.06320631 0.37293489 0.40023175]
# Final Likelihood: 3648.700645402222
# 14
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -336.48869432562765
# `xtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 225, CG iterations: 153, optimality: 6.00e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [2.21435215 2.07673659 0.39875144 0.38276072]
# Final Likelihood: 3529.252326805494
# 15
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -264.97612888171204
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 295, CG iterations: 184, optimality: 6.47e-05, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [1.91997265 2.07720476 0.38735996 0.38338391]
# Final Likelihood: 3613.1035824451346
# 16
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -414.15484355455214
# `xtol` termination condition is satisfied.
# Number of iterations: 55, function evaluations: 250, CG iterations: 155, optimality: 4.65e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [2.82232339 2.09195381 0.38740005 0.38622747]
# Final Likelihood: 3531.549388330267
# 17
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -368.4808004937395
# `xtol` termination condition is satisfied.
# Number of iterations: 73, function evaluations: 340, CG iterations: 202, optimality: 1.74e-04, constraint violation: 0.00e+00, execution time: 0.33 s.
# Final Params: [2.37321061 2.10482555 0.38676062 0.38830998]
# Final Likelihood: 3541.5056353320615
# 18
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -98.63673745916913
# `xtol` termination condition is satisfied.
# Number of iterations: 72, function evaluations: 345, CG iterations: 210, optimality: 1.44e-04, constraint violation: 0.00e+00, execution time: 0.35 s.
# Final Params: [0.89621393 2.17829775 0.37733891 0.39273213]
# Final Likelihood: 3681.4875275139602
# 19
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -154.7190338051414
# `xtol` termination condition is satisfied.
# Number of iterations: 59, function evaluations: 280, CG iterations: 172, optimality: 1.02e-04, constraint violation: 0.00e+00, execution time: 0.27 s.
# Final Params: [0.5335093  2.19785066 0.37681018 0.39033824]
# Final Likelihood: 3673.610832429945
# 20
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 116.43414411760182
# `xtol` termination condition is satisfied.
# Number of iterations: 63, function evaluations: 275, CG iterations: 166, optimality: 5.34e-05, constraint violation: 0.00e+00, execution time: 0.28 s.
# Final Params: [5.02776409e-05 2.23276781e+00 3.64329063e-01 3.96800759e-01]
# Final Likelihood: 3822.725956949687
# 21
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -285.0494712169228
# `xtol` termination condition is satisfied.
# Number of iterations: 50, function evaluations: 240, CG iterations: 142, optimality: 1.69e-04, constraint violation: 0.00e+00, execution time: 0.24 s.
# Final Params: [0.76032992 2.19291771 0.3837757  0.37900994]
# Final Likelihood: 3650.011882733187
# 22
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -358.578391587492
# `xtol` termination condition is satisfied.
# Number of iterations: 101, function evaluations: 500, CG iterations: 273, optimality: 1.84e-04, constraint violation: 0.00e+00, execution time: 0.49 s.
# Final Params: [1.39075729 2.21268285 0.36886561 0.38523842]
# Final Likelihood: 3659.286095506801
# 23
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -404.673878252195
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 265, CG iterations: 178, optimality: 3.79e-04, constraint violation: 0.00e+00, execution time: 0.27 s.
# Final Params: [1.7962137  2.1851301  0.33356271 0.41561935]
# Final Likelihood: 3648.660264642921
# 24
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -342.03468421379876
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 375, CG iterations: 210, optimality: 6.23e-05, constraint violation: 0.00e+00, execution time: 0.34 s.
# Final Params: [1.46165127 2.22388293 0.32185025 0.42302045]
# Final Likelihood: 3702.864255547159
# 25
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -338.79590701130553
# `xtol` termination condition is satisfied.
# Number of iterations: 87, function evaluations: 420, CG iterations: 238, optimality: 4.89e-05, constraint violation: 0.00e+00, execution time: 0.41 s.
# Final Params: [1.20974718 2.26508138 0.30869613 0.42907187]
# Final Likelihood: 3750.3557652910854
# 26
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -103.64845227580167
# `xtol` termination condition is satisfied.
# Number of iterations: 78, function evaluations: 395, CG iterations: 235, optimality: 6.03e-05, constraint violation: 0.00e+00, execution time: 0.38 s.
# Final Params: [0.01406539 2.27408874 0.31863844 0.41933286]
# Final Likelihood: 3857.3687023592074
# 27
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 54.00218106429975
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 330, CG iterations: 205, optimality: 9.71e-06, constraint violation: 0.00e+00, execution time: 0.36 s.
# Final Params: [4.98073652e-06 2.29417447e+00 3.17779573e-01 4.07068706e-01]
# Final Likelihood: 4006.911656269119
# 28
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -217.03139033731418
# `xtol` termination condition is satisfied.
# Number of iterations: 76, function evaluations: 365, CG iterations: 241, optimality: 9.18e-05, constraint violation: 0.00e+00, execution time: 0.37 s.
# Final Params: [0.51655987 2.29556461 0.35061899 0.38273347]
# Final Likelihood: 3836.490465461145
# 29
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -323.47602895453633
# `xtol` termination condition is satisfied.
# Number of iterations: 58, function evaluations: 275, CG iterations: 175, optimality: 1.97e-04, constraint violation: 0.00e+00, execution time: 0.28 s.
# Final Params: [0.88706114 2.30948889 0.35679185 0.37588465]
# Final Likelihood: 3798.661263673048
# 30
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -618.1933086060591
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 265, CG iterations: 188, optimality: 4.70e-05, constraint violation: 0.00e+00, execution time: 0.28 s.
# Final Params: [2.0705561  2.27054962 0.34622461 0.38130143]
# Final Likelihood: 3699.5508890607653
# 31
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -231.00634258390755
# `xtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 290, CG iterations: 185, optimality: 7.76e-05, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [0.61119444 2.26390945 0.33328477 0.40282535]
# Final Likelihood: 3808.869567343774
# 32
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -230.19438853362544
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 300, CG iterations: 181, optimality: 1.20e-04, constraint violation: 0.00e+00, execution time: 0.27 s.
# Final Params: [0.47361707 2.25962836 0.3444011  0.39430988]
# Final Likelihood: 3795.564601892559
# 33
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -426.8654849413381
# `xtol` termination condition is satisfied.
# Number of iterations: 82, function evaluations: 410, CG iterations: 216, optimality: 1.91e-04, constraint violation: 0.00e+00, execution time:  0.4 s.
# Final Params: [1.37275375 2.25885558 0.34685174 0.396513  ]
# Final Likelihood: 3681.52916945852
# 34
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -380.3828856877675
# `xtol` termination condition is satisfied.
# Number of iterations: 71, function evaluations: 350, CG iterations: 184, optimality: 2.80e-04, constraint violation: 0.00e+00, execution time: 0.34 s.
# Final Params: [1.56719367 2.21093383 0.34591397 0.39461926]
# Final Likelihood: 3719.6430881725187
# 35
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -272.14930903101003
# `xtol` termination condition is satisfied.
# Number of iterations: 80, function evaluations: 385, CG iterations: 201, optimality: 5.60e-05, constraint violation: 0.00e+00, execution time: 0.39 s.
# Final Params: [1.00542627 2.23904562 0.34202426 0.39751978]
# Final Likelihood: 3771.4931481331905
# 36
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -433.2611489914011
# `xtol` termination condition is satisfied.
# Number of iterations: 91, function evaluations: 440, CG iterations: 258, optimality: 9.00e-05, constraint violation: 0.00e+00, execution time: 0.43 s.
# Final Params: [1.43676093 2.25345119 0.3396596  0.39893571]
# Final Likelihood: 3704.783641609789
# 37
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -510.67575070940313
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 335, CG iterations: 235, optimality: 1.71e-04, constraint violation: 0.00e+00, execution time: 0.37 s.
# Final Params: [1.70514153 2.26583298 0.3278089  0.41347443]
# Final Likelihood: 3648.3250835036724
# 38
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -290.2837676225208
# `xtol` termination condition is satisfied.
# Number of iterations: 68, function evaluations: 300, CG iterations: 214, optimality: 5.02e-04, constraint violation: 0.00e+00, execution time: 0.33 s.
# Final Params: [0.74742765 2.28397389 0.31414512 0.42162853]
# Final Likelihood: 3784.305054082247
# 39
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -521.1874453641719
# `xtol` termination condition is satisfied.
# Number of iterations: 78, function evaluations: 365, CG iterations: 240, optimality: 1.07e-03, constraint violation: 0.00e+00, execution time: 0.39 s.
# Final Params: [1.62553492 2.29571674 0.30592014 0.42624437]
# Final Likelihood: 3699.030691637052
# 40
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -588.5419127109957
# `xtol` termination condition is satisfied.
# Number of iterations: 99, function evaluations: 475, CG iterations: 304, optimality: 1.40e-04, constraint violation: 0.00e+00, execution time: 0.49 s.
# Final Params: [1.84260974 2.27588874 0.31484188 0.42652197]
# Final Likelihood: 3608.191172745233
# 41
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -440.1043211724956
# `xtol` termination condition is satisfied.
# Number of iterations: 57, function evaluations: 245, CG iterations: 174, optimality: 1.53e-04, constraint violation: 0.00e+00, execution time: 0.26 s.
# Final Params: [1.46403218 2.25771577 0.31676586 0.42225861]
# Final Likelihood: 3693.5234892859835
# 42
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -374.9324583539244
# `xtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 265, CG iterations: 179, optimality: 1.61e-04, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [1.22486794 2.25541681 0.30776984 0.43774916]
# Final Likelihood: 3684.421393751414
# 43
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -310.8148594475467
# `xtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 305, CG iterations: 185, optimality: 1.21e-04, constraint violation: 0.00e+00, execution time: 0.31 s.
# Final Params: [1.13031304 2.2518069  0.31633215 0.43473892]
# Final Likelihood: 3679.884786516414
# 44
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -468.11766433827006
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 370, CG iterations: 206, optimality: 1.61e-04, constraint violation: 0.00e+00, execution time: 0.36 s.
# Final Params: [1.44574644 2.25526375 0.32211525 0.43460054]
# Final Likelihood: 3568.425115138434
# 45
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -340.53640480943704
# `xtol` termination condition is satisfied.
# Number of iterations: 74, function evaluations: 365, CG iterations: 213, optimality: 1.10e-04, constraint violation: 0.00e+00, execution time: 0.36 s.
# Final Params: [0.98070032 2.25974206 0.35711384 0.39977349]
# Final Likelihood: 3641.57719980696
# 46
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -187.89369318899116
# `xtol` termination condition is satisfied.
# Number of iterations: 54, function evaluations: 235, CG iterations: 154, optimality: 1.30e-04, constraint violation: 0.00e+00, execution time: 0.24 s.
# Final Params: [0.72288883 2.27136452 0.35339371 0.40619148]
# Final Likelihood: 3691.8929415570055
# 47
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -581.2491282167573
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 250, CG iterations: 181, optimality: 2.87e-05, constraint violation: 0.00e+00, execution time: 0.27 s.
# Final Params: [1.88433487 2.23502633 0.34741364 0.40689508]
# Final Likelihood: 3542.2219872341625
# 48
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -334.15666242071643
# `xtol` termination condition is satisfied.
# Number of iterations: 70, function evaluations: 335, CG iterations: 196, optimality: 1.93e-04, constraint violation: 0.00e+00, execution time: 0.33 s.
# Final Params: [1.15075156 2.23524729 0.33181494 0.4161919 ]
# Final Likelihood: 3688.4342564812505
# 49
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -205.03958733821742
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 315, CG iterations: 192, optimality: 5.96e-05, constraint violation: 0.00e+00, execution time: 0.34 s.
# Final Params: [1.06516807 2.22961653 0.35032232 0.39884274]
# Final Likelihood: 3745.6856778094843
# 50
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -472.69239773601055
# `xtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 245, CG iterations: 164, optimality: 5.32e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [2.24064173 2.19924835 0.36577731 0.38271966]
# Final Likelihood: 3642.9171382218124
# 51
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -350.458803880764
# `xtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 330, CG iterations: 205, optimality: 3.67e-04, constraint violation: 0.00e+00, execution time: 0.32 s.
# Final Params: [1.57275504 2.2071961  0.37147078 0.38510692]
# Final Likelihood: 3650.0136835140906
# 52
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -602.3151125362023
# `xtol` termination condition is satisfied.
# Number of iterations: 59, function evaluations: 240, CG iterations: 177, optimality: 9.52e-05, constraint violation: 0.00e+00, execution time: 0.26 s.
# Final Params: [2.62598936 2.21729947 0.38312076 0.38231266]
# Final Likelihood: 3498.226432423193
# 53
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -408.3584249062859
# `xtol` termination condition is satisfied.
# Number of iterations: 51, function evaluations: 215, CG iterations: 151, optimality: 2.58e-04, constraint violation: 0.00e+00, execution time: 0.23 s.
# Final Params: [1.70752718 2.21776913 0.39674908 0.37395682]
# Final Likelihood: 3564.152580560778
# 54
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -356.710973489284
# `xtol` termination condition is satisfied.
# Number of iterations: 63, function evaluations: 295, CG iterations: 194, optimality: 2.04e-04, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [1.27143271 2.22532197 0.427957   0.34955548]
# Final Likelihood: 3586.8151961452286
# 55
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -151.40602474170555
# `xtol` termination condition is satisfied.
# Number of iterations: 51, function evaluations: 220, CG iterations: 143, optimality: 9.04e-05, constraint violation: 0.00e+00, execution time: 0.23 s.
# Final Params: [0.80331481 2.2319796  0.41408299 0.36420998]
# Final Likelihood: 3644.9178423976664
# 56
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -454.05111649619516
# `xtol` termination condition is satisfied.
# Number of iterations: 97, function evaluations: 460, CG iterations: 262, optimality: 1.00e-04, constraint violation: 0.00e+00, execution time: 0.46 s.
# Final Params: [1.23772949 2.25044349 0.42039529 0.37227143]
# Final Likelihood: 3440.4371040810715
# 57
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -285.08536321152474
# `xtol` termination condition is satisfied.
# Number of iterations: 59, function evaluations: 260, CG iterations: 155, optimality: 2.07e-04, constraint violation: 0.00e+00, execution time: 0.28 s.
# Final Params: [1.16529571 2.21695759 0.41681308 0.3802751 ]
# Final Likelihood: 3479.192369776608
# 58
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -411.50776756380833
# `xtol` termination condition is satisfied.
# Number of iterations: 72, function evaluations: 350, CG iterations: 205, optimality: 1.10e-04, constraint violation: 0.00e+00, execution time: 0.35 s.
# Final Params: [1.57288193 2.17457954 0.41675493 0.38665314]
# Final Likelihood: 3384.89667904713
# 59
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -156.27373884906262
# `xtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 240, CG iterations: 156, optimality: 4.16e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [0.61214608 2.21888169 0.40368832 0.38720932]
# Final Likelihood: 3555.3812858022843
# 60
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -225.27737990936885
# `xtol` termination condition is satisfied.
# Number of iterations: 57, function evaluations: 265, CG iterations: 171, optimality: 1.32e-04, constraint violation: 0.00e+00, execution time: 0.28 s.
# Final Params: [0.88426469 2.21683966 0.43656826 0.36515223]
# Final Likelihood: 3504.1637161808767
# 61
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -125.90145880661112
# `xtol` termination condition is satisfied.
# Number of iterations: 211, function evaluations: 1040, CG iterations: 613, optimality: 2.84e-04, constraint violation: 0.00e+00, execution time:  1.1 s.
# Final Params: [0.02620336 2.26493259 0.43973219 0.35849452]
# Final Likelihood: 3569.5494307116496
# 62
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 459.10476136142404
# `xtol` termination condition is satisfied.
# Number of iterations: 70, function evaluations: 300, CG iterations: 195, optimality: 4.94e-05, constraint violation: 0.00e+00, execution time: 0.32 s.
# Final Params: [1.63557500e-05 2.22361384e+00 4.35420418e-01 3.60018193e-01]
# Final Likelihood: 3816.382247331755
# 63
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -365.87165920203233
# `xtol` termination condition is satisfied.
# Number of iterations: 79, function evaluations: 375, CG iterations: 235, optimality: 2.10e-04, constraint violation: 0.00e+00, execution time:  0.4 s.
# Final Params: [1.63733331 2.18384865 0.47549451 0.34104881]
# Final Likelihood: 3426.8574820298895
# 64
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -342.9587929515326
# `xtol` termination condition is satisfied.
# Number of iterations: 53, function evaluations: 235, CG iterations: 153, optimality: 7.55e-05, constraint violation: 0.00e+00, execution time: 0.23 s.
# Final Params: [1.26111931 2.21681692 0.47837246 0.34170275]
# Final Likelihood: 3419.6439640050958
# 65
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -654.846580322154
# `xtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 260, CG iterations: 190, optimality: 3.89e-05, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [2.50018784 2.21266618 0.45551447 0.35773333]
# Final Likelihood: 3292.568410129502
# 66
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -271.1086190767203
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 310, CG iterations: 197, optimality: 4.52e-04, constraint violation: 0.00e+00, execution time: 0.34 s.
# Final Params: [1.60819736 2.15570886 0.47235258 0.34593436]
# Final Likelihood: 3446.7877990080533
# 67
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -108.29810487936993
# `xtol` termination condition is satisfied.
# Number of iterations: 70, function evaluations: 330, CG iterations: 204, optimality: 1.08e-04, constraint violation: 0.00e+00, execution time: 0.35 s.
# Final Params: [0.92296816 2.14499261 0.45895519 0.35557286]
# Final Likelihood: 3509.3912067697347
# 68
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 47.740667624970115
# `xtol` termination condition is satisfied.
# Number of iterations: 59, function evaluations: 240, CG iterations: 162, optimality: 5.13e-05, constraint violation: 0.00e+00, execution time: 0.27 s.
# Final Params: [2.07051637e-05 2.21429452e+00 4.65050589e-01 3.55453707e-01]
# Final Likelihood: 3546.2145785812063
# 69
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 398.8578639405989
# `xtol` termination condition is satisfied.
# Number of iterations: 68, function evaluations: 310, CG iterations: 178, optimality: 1.55e-04, constraint violation: 0.00e+00, execution time: 0.35 s.
# Final Params: [4.21622821e-06 2.20531050e+00 4.68007077e-01 3.59674640e-01]
# Final Likelihood: 3651.0562899902648
# 70
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 61.6913738722543
# `xtol` termination condition is satisfied.
# Number of iterations: 54, function evaluations: 230, CG iterations: 146, optimality: 1.42e-04, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [6.08028911e-05 2.22807468e+00 4.68445090e-01 3.53870222e-01]
# Final Likelihood: 3546.357095211983
# 71
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 457.6119050000733
# `xtol` termination condition is satisfied.
# Number of iterations: 64, function evaluations: 320, CG iterations: 179, optimality: 1.10e-04, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [2.36805662e-05 2.25827469e+00 4.68890938e-01 3.57741177e-01]
# Final Likelihood: 3682.545241576915
# 72
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -143.3655921841414
# `xtol` termination condition is satisfied.
# Number of iterations: 93, function evaluations: 440, CG iterations: 262, optimality: 6.26e-05, constraint violation: 0.00e+00, execution time: 0.47 s.
# Final Params: [0.45888205 2.21057404 0.45283351 0.37115173]
# Final Likelihood: 3428.9772764146674
# 73
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 474.6423032603824
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 305, CG iterations: 144, optimality: 5.16e-05, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [3.35120996e-06 2.19785253e+00 4.61983368e-01 3.64284138e-01]
# Final Likelihood: 3682.7059861425587
# 74
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 429.68486011907964
# `xtol` termination condition is satisfied.
# Number of iterations: 61, function evaluations: 250, CG iterations: 163, optimality: 4.16e-05, constraint violation: 0.00e+00, execution time: 0.28 s.
# Final Params: [4.93396399e-06 2.16829061e+00 4.63443659e-01 3.64344888e-01]
# Final Likelihood: 3657.8624821199382
# 75
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -62.61429505886417
# `xtol` termination condition is satisfied.
# Number of iterations: 49, function evaluations: 200, CG iterations: 120, optimality: 4.92e-04, constraint violation: 0.00e+00, execution time: 0.23 s.
# Final Params: [0.77445186 2.17097762 0.45647875 0.37111798]
# Final Likelihood: 3447.3372219292696
# 76
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -103.02218788433254
# `xtol` termination condition is satisfied.
# Number of iterations: 76, function evaluations: 365, CG iterations: 206, optimality: 1.65e-04, constraint violation: 0.00e+00, execution time: 0.39 s.
# Final Params: [1.10029881 2.12164394 0.44225492 0.38349442]
# Final Likelihood: 3419.7898835946953
# 77
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -122.24177567947106
# `xtol` termination condition is satisfied.
# Number of iterations: 58, function evaluations: 260, CG iterations: 160, optimality: 1.88e-04, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [0.96366366 2.1369535  0.42653698 0.3913292 ]
# Final Likelihood: 3436.371585491851
# 78
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -172.4258765012114
# `xtol` termination condition is satisfied.
# Number of iterations: 83, function evaluations: 395, CG iterations: 237, optimality: 6.54e-05, constraint violation: 0.00e+00, execution time: 0.42 s.
# Final Params: [0.71995247 2.17950295 0.44758591 0.38020619]
# Final Likelihood: 3385.921633181431
# 79
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -290.3461675794242
# `xtol` termination condition is satisfied.
# Number of iterations: 57, function evaluations: 275, CG iterations: 149, optimality: 6.48e-05, constraint violation: 0.00e+00, execution time: 0.27 s.
# Final Params: [1.35913656 2.19662805 0.45979847 0.37716942]
# Final Likelihood: 3301.156135264878
# 80
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -522.1297057282476
# `xtol` termination condition is satisfied.
# Number of iterations: 52, function evaluations: 215, CG iterations: 150, optimality: 4.17e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [2.29466266 2.19833418 0.48392769 0.35773861]
# Final Likelihood: 3225.769920826936
# 81
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -218.8912447629359
# `xtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 260, CG iterations: 151, optimality: 1.85e-04, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [0.73095451 2.23521226 0.47419953 0.37210782]
# Final Likelihood: 3301.153794675518
# 82
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 119.4876587524144
# `xtol` termination condition is satisfied.
# Number of iterations: 79, function evaluations: 375, CG iterations: 226, optimality: 6.45e-05, constraint violation: 0.00e+00, execution time: 0.38 s.
# Final Params: [0.09177548 2.20592523 0.48641272 0.36452434]
# Final Likelihood: 3434.891713852654
# 83
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 209.87191728435778
# `xtol` termination condition is satisfied.
# Number of iterations: 53, function evaluations: 205, CG iterations: 152, optimality: 2.91e-05, constraint violation: 0.00e+00, execution time: 0.23 s.
# Final Params: [7.46294128e-04 2.15069878e+00 5.00429919e-01 3.62911262e-01]
# Final Likelihood: 3424.688275618102
# 84
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: 278.3560266502267
# `xtol` termination condition is satisfied.
# Number of iterations: 82, function evaluations: 390, CG iterations: 222, optimality: 1.51e-04, constraint violation: 0.00e+00, execution time: 0.39 s.
# Final Params: [0.12681707 2.08969177 0.48033432 0.37918275]
# Final Likelihood: 3443.825944075543
# 85
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -133.32634605423743
# `xtol` termination condition is satisfied.
# Number of iterations: 52, function evaluations: 210, CG iterations: 154, optimality: 1.04e-04, constraint violation: 0.00e+00, execution time: 0.23 s.
# Final Params: [1.27480768 2.12589748 0.46290897 0.3935068 ]
# Final Likelihood: 3256.7147533665075
# 86
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -304.8119702894271
# `xtol` termination condition is satisfied.
# Number of iterations: 68, function evaluations: 315, CG iterations: 189, optimality: 7.10e-04, constraint violation: 0.00e+00, execution time: 0.33 s.
# Final Params: [2.07063391 2.09973992 0.47306523 0.39399097]
# Final Likelihood: 3135.017256920678
# 87
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -256.3953786693362
# `xtol` termination condition is satisfied.
# Number of iterations: 78, function evaluations: 365, CG iterations: 216, optimality: 9.02e-05, constraint violation: 0.00e+00, execution time: 0.38 s.
# Final Params: [2.03550208 2.08328941 0.48085842 0.38749703]
# Final Likelihood: 3164.0426400842125
# 88
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -146.330707439418
# `xtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 290, CG iterations: 159, optimality: 1.40e-04, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [1.77863123 2.04788012 0.47104979 0.39259135]
# Final Likelihood: 3221.5326544683503
# 89
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -56.51561283684259
# `xtol` termination condition is satisfied.
# Number of iterations: 51, function evaluations: 265, CG iterations: 138, optimality: 5.82e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [1.10893226 2.06258151 0.48856086 0.38160492]
# Final Likelihood: 3253.481364937592
# 90
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -0.4080055152608111
# `xtol` termination condition is satisfied.
# Number of iterations: 74, function evaluations: 340, CG iterations: 202, optimality: 1.86e-05, constraint violation: 0.00e+00, execution time: 0.35 s.
# Final Params: [1.83498316 2.00897038 0.46725407 0.39618726]
# Final Likelihood: 3281.900283529059
# 91
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -332.311153313554
# `xtol` termination condition is satisfied.
# Number of iterations: 55, function evaluations: 245, CG iterations: 152, optimality: 3.78e-05, constraint violation: 0.00e+00, execution time: 0.25 s.
# Final Params: [2.81174029 1.98550615 0.49662609 0.36792848]
# Final Likelihood: 3187.4262563320262
# 92
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -254.5449751908659
# `xtol` termination condition is satisfied.
# Number of iterations: 55, function evaluations: 225, CG iterations: 155, optimality: 6.34e-05, constraint violation: 0.00e+00, execution time: 0.26 s.
# Final Params: [2.57419673 1.98414877 0.49683055 0.36421479]
# Final Likelihood: 3241.1166391911556
# 93
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -118.49492261055684
# `xtol` termination condition is satisfied.
# Number of iterations: 88, function evaluations: 430, CG iterations: 244, optimality: 6.95e-05, constraint violation: 0.00e+00, execution time: 0.45 s.
# Final Params: [2.24870134 1.98057159 0.43859123 0.39896376]
# Final Likelihood: 3337.2801108015815
# 94
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -328.12165524175373
# `xtol` termination condition is satisfied.
# Number of iterations: 80, function evaluations: 405, CG iterations: 222, optimality: 1.87e-04, constraint violation: 0.00e+00, execution time: 0.39 s.
# Final Params: [3.01485017 1.94993305 0.45013837 0.3867107 ]
# Final Likelihood: 3267.4811946706395
# 95
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -450.5997200302427
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 325, CG iterations: 189, optimality: 9.92e-05, constraint violation: 0.00e+00, execution time: 0.31 s.
# Final Params: [4.16920624 1.92480916 0.44856751 0.38534099]
# Final Likelihood: 3229.8972836737707
# 96
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -537.4751032333731
# `xtol` termination condition is satisfied.
# Number of iterations: 86, function evaluations: 445, CG iterations: 233, optimality: 3.25e-05, constraint violation: 0.00e+00, execution time: 0.42 s.
# Final Params: [4.67497985 1.89635402 0.46739515 0.37994919]
# Final Likelihood: 3146.485007981819
# 97
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -932.6067769310204
# `xtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 345, CG iterations: 182, optimality: 3.37e-05, constraint violation: 0.00e+00, execution time: 0.29 s.
# Final Params: [4.99999604 1.91967418 0.50500969 0.36393998]
# Final Likelihood: 2933.7681271781316
# 98
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -369.906423089044
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 370, CG iterations: 219, optimality: 7.24e-05, constraint violation: 0.00e+00, execution time: 0.37 s.
# Final Params: [3.15148028 1.96238073 0.55177699 0.34183277]
# Final Likelihood: 3124.50001408718
# 99
# Initial Params: [0.5 0.9 0.9 0.9]
# Initial Likelihood: -689.9289436547123
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 350, CG iterations: 179, optimality: 2.38e-05, constraint violation: 0.00e+00, execution time: 0.32 s.
# Final Params: [4.99991677 1.94258756 0.53252529 0.34590658]
# Final Likelihood: 3046.109821624399
# Theta_1:  (1.098541130588886, 1.5150998447841686)
# Theta_2:  (2.1378163903249616, 2.179351852146641)
# Theta_3:  (0.3993794693086316, 0.4243818806903262)
# Theta_4:  (0.3749852143702948, 0.38630102563819474)
#
# Euler MLE:
# params      | [4.99991677 1.94258756 0.53252529 0.34590658]
# sample size | 2000
# likelihood  | 3046.109821624399
# AIC         | -6084.219643248798
# BIC         | -6061.81603341063

# %%
print(f"Theta_1 = {np.array(theta1).mean()}, Theta_2 = {np.array(theta2).mean()}")
print(f"Theta_3 = {np.array(theta3).mean()}, Theta_4 = {np.array(theta4).mean()}")
# Out:
# Theta_1 = 1.3068204876865273, Theta_2 = 2.1585841212358012
# Theta_3 = 0.4118806749994789, Theta_4 = 0.3806431200042448
